# %%
import numpy as np
import pandas as pd

path ='filariasis.csv'
df = pd.read_csv(path)
df.columns
# Out:
# Index(['Disease', 'Disease.keyword', 'ExtractedDate', 'ExtractedDateTime',
#        'Incident', 'Incident.keyword', 'Incident_Type',
#        'Incident_Type.keyword', 'Incident_type', 'Incident_type.keyword',
#        'Language', 'Language.keyword', 'Location', 'Location.keyword',
#        'MLPipelineVersion', 'MLPipelineVersion.keyword', 'Number',
#        'OriginalArticle', 'OriginalArticle.keyword', 'Score', 'Source',
#        'Source.keyword', 'Start', 'TranslatedArticle',
#        'TranslatedArticle.keyword', 'Url', 'Url.keyword', '_id', '_index',
#        '_score', '_type'],
#       dtype='object')

# %%
df2 = df["TranslatedArticle"]
df2.to_csv("Translated.csv")

# %%
text=df2[0]
text
# Out:
# '6615 patients of filariasis in the district 158 patients got the benefit of operation. The district has 6615 patients of Filariasis. In these patients...'

# %%
from selenium import webdriver

url = "https://udaaniitb.aicte-india.org/udaan/translate/"

driver = webdriver.Chrome("/Users/balbirsingh/Desktop/chromedriver/chromedrive")

driver.get(url)
# Out:
# /var/folders/yn/bb4yp_pj2p5742vtvn9nw0980000gn/T/ipykernel_65010/2186445984.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/balbirsingh/Desktop/chromedriver/chromedrive")

# %%
from selenium.webdriver.common.by import By
input = 'inp_text'
driver.find_element(By.NAME,input).send_keys(text)

# %%
from selenium.webdriver.support.ui import Select

import time
select = Select(driver.find_element(By.NAME,'sel_dict'))

# select by visible text
time.sleep(0.8)
#select.select_by_visible_text('None')

#select.select_by_value('none')

# %%
select.select_by_value('none')

# %%
translate ="btn-primary"
driver.find_element(By.CLASS_NAME,translate).click()
time.sleep(1)

# %%
output = "out_text"
tranlated_text = driver.find_element(By.NAME,output).get_attribute('value')

# %%
print(tranlated_text)
# Out:
# जिले में फाइलेरिया के 6615 मरीजों को संचालन का लाभ मिला है, जिले में फाइलेरिया के 6615 मरीज हैं।

# %%
# import requests

# url = "https://udaaniitb.aicte-india.org/udaan/translate/"

# payload = 'csrfmiddlewaretoken=x4ToOnWJa4aRb1ueDtjKjrUxBnizn841Hz07qTXLERWNzbpY3LBpbLgjAujcK6mI&inp_text=how%20are%20you%20doing&out_text=&sel_dict=none'
# headers = {
#   'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Accept-Language': 'en-US,en;q=0.9',
#   'Cache-Control': 'max-age=0',
#   'Connection': 'keep-alive',
#   'Content-Length': '135',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Cookie': 'csrftoken=Ktf7FKkzpMNcRzbcF4dcEuoviRa4v9fmUYmQhglBTzz8fJ6W5mvRwOKhhYbHS7x3; csrftoken=Ktf7FKkzpMNcRzbcF4dcEuoviRa4v9fmUYmQhglBTzz8fJ6W5mvRwOKhhYbHS7x3',
#   'Host': 'udaaniitb.aicte-india.org',
#   'Origin': 'https://udaaniitb.aicte-india.org',
#   'Referer': 'https://udaaniitb.aicte-india.org/udaan/translate/',
#   'sec-ch-ua': '"Chromium";v="112", "Brave";v="112", "Not:A-Brand";v="99"',
#   'sec-ch-ua-mobile': '0',
#   'sec-ch-ua-platform': '"Windows"',
#   'Sec-Fetch-Dest': 'document',
#   'Sec-Fetch-Mode': 'navigate',
#   'Sec-Fetch-Site': 'same-origin',
#   'Sec-Fetch-User': '1',
#   'Sec-GPC': '1',
#   'Upgrade-Insecure-Requests': '1',
#   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
# }

# response = requests.request("POST", url, headers=headers, data=payload)

# print(response.text)

# %%
# importing the modules
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import time

# using chrome driver
driver=webdriver.Chrome()

# web page url
driver.get("https://fs2.formsite.com/meherpavan/form2/index.html?1537702596407")

# find id of option
x = driver.find_element(By.ID,'RESULT_RadioButton-9')
drop=Select(x)

# select by visible text
drop.select_by_visible_text("Afternoon")
time.sleep(4)

# %%
dt2 = "300 से अधिक लोगों का परीक्षण किया गया, फाइलेरियासिस के लिए तीस लोगों का परीक्षण किया गया, फाइलेरियासिस के लिए तीस लोगों का परीक्षण किया गया, सीएमओ के निर्देशन में उनानो, उनानो, नई बस्ती और श्रदा नगर में फाइलेरियासिस के मरीज पाए गए, फाइलेरियासिस उन्मूलन कार्यक्रम के तहत नेटुआ ग्राम सभा के स्वास्थ्य कार्यकर्ताओं ने शिविरों का संचालन किया और अजाद नगर, नई बस्ती और शरदा नगर में प्रत्येक घर से रक्त के नमूने एकत्र किए गए।:::सोमवार को मेहर में फाइलेरियासिस का पहला मामला सामने आया, जिसके बाद मैहर और अमरपाटन ब्लॉक में चार नए मामले सामने आए, जो ट्यूसडे पर भी सामने आए, चार और बच्चों में फाइलेरिया संक्रमण की पुष्टि हुई, कुल मामलों में 5 की वृद्धि हुई:::हाल ही में लिए गए 3400 नमूनों में से 4200 नमूनों में से, सूक्ष्म फाइलेरिया वाले 20 मरीजों को पॉजिटिव पाया गया है।:::हाथियों के बारे में 9,688 लोगों के रक्त नमूनों का संग्रह कुल 9,688 नमूने एकत्र किए गए थे, जिनमें से लक्षण केवल रात में हो सकते हैं।:::मुंगेर में फाइलेरिया रोगियों की संख्या में वृद्धि क्यूलेक्स मच्छरों के प्रकोप का एक प्रमुख कारण है. जिले के लोगों को फाइलेरिया से बचने के लिए सावधान रहने की आवश्यकता है. जिले में फाइलेरिया रोगियों की कुल संख्या बढ़कर 5,252 हो गई है।:::फाइलेरिया परीक्षण किया गया, 7 मरीजों ने पाया कि विभाग ने 60 लोगों के लिए रक्त के नमूने एकत्र किए, जहाँ आशा सहायकों ने लोगों को सतर्क किया, इसके बाद लगभग 60 लोगों के रक्त के नमूने एकत्र किए गए, जिनमें से सात फाइलेरिया से संक्रमित पाए गए।:::सागर जिले में, 'हैथिपव' के दो नए मरीज वायरस से संक्रमित पाए गए हैं. सर्वेक्षण के दौरान, सागर के 36 स्कूलों में 741 बच्चों का सर्वेक्षण किया गया, जिनमें से दो फाइलेरिया से संक्रमित पाए गए।:::झारखंड के पलामू जिले में स्कूली बच्चों को फाइलेरियासिस दवा दी गई थी, जहां 15 बच्चे इसका उपयोग करने के बाद बीमार पड़ गए थे।:::आज से मरीजों की पहचान, पोटका में रात सर्वेक्षण के लिए किटों का वितरण किया जाएगा। पूर्वी सिंहभूम में फाइलेरियासिस के 1790 मामलों की पहचान की गई है।:::झारखंड में फाइलेरियासिस: 51,000 से अधिक लोग बीमारी से पीड़ित हैं. राज्य में फाइलेरियासिस से पीड़ित 51,000 लोग हैं. इनमें से अधिकांश देवघर में हैं।:::फाइलेरिया रोगियों की संख्या में कमी, जिला स्वास्थ्य विभाग की फाइलेरिया शाखा के अनुसार नए मामलों में वृद्धि, फाइलेरिया के साथ 113 रोगी हैं, साथ ही, फाइलेरिया के रोगियों के बारे में अधिक जानकारी प्राप्त करने के लिए जिले भर में सर्वेक्षण भी किए जा रहे हैं।:::राष्ट्रीय फाइलेरिया दिवस पर विशेष फीलारियासिस दिवस-राष्ट्रीय फिलारियासिस दिवस आज कामालगंज सीएचसी, फर्रुखाबाद में मनाया जाएगा।:::फाइलेरिया, संक्रमण, बुंदेलखंड, निवाड़ी, थुना गांव, 11 नए मरीज, मच्छरों द्वारा फाइलेरिया को काटने से एक बार फिर बुंदेलखंड में फैल रहा है।:::मिर्जापुर में फाइलेरिया का केस 150 मार्क्स को पार कर गया है, जिसे पढ़ने के बाद पता चलता है कि मिर्जापुर में नोक न्यूज18 फाइलेरिया है, यह बीमारी शहरी क्षेत्रों के साथ<unk> साथ ग्रामीण क्षेत्रों में भी तेजी से फैल रही है।:::राज्य में कोरोना वायरस के एक और मामले की पुष्टि की गई है। स्वास्थ्य विभाग के एमआईएसटी (मोबाइल प्रवासियों की स्क्रीनिंग टीम) द्वारा इस बीमारी के लिए 60 वर्षीय आदिवासी महिला का परीक्षण किया गया है।"

# %%
dt5 = "17 वर्षों से अभियान अभी भी जिला फाइलेरिया को प्रमाणित नहीं कर पाया है, जिले में 1328 मरीजों का उपचार चल रहा है, हालांकि, पिछले नौ वर्षों से मरीजों की संख्या समान रही है।:::महाराष्ट्रः नागपुर में फाइलेरिया के 12 नए मरीजों के आगमन से स्तब्ध, इस वर्ष के सर्वेक्षण के बाद सबसे अधिक संख्या में मामले सामने आए हैं, नागपुर में फाइलेरिया के 12 नए मामले सामने आए हैं। इस वर्ष, फाइलेरिया के सबसे अधिक मामले 2018 से रिपोर्ट किए गए हैं।:::मुज़फ्फरपुर में फाइलेरिया से छुटकारा पाने के लिए रात के रक्त का सर्वेक्षण किया जाएगा, जिसमें रोगियों को क्या लाभ होगा, डेटा स्पष्ट होने के बाद, आईडीए अभियान को सर्व जन औषधि पारियोजना में प्रारंभ किया जाएगा।:::फाइलेरिया को जिला फाइलेरिया मुक्त बनाने के लिए सितंबर से 12 तक लगभग 7 लाख लोगों को दवाएं दी जाएंगी, विभाग की टीम उनके सामने लोगों को दवाएं प्रदान करेगी।:::यहाँ यह है कि कैसे कर्णाटक स्वास्थ्य अधिकारी यह सुनिश्चित कर रहे हैं कि लसीका फाइलरियासिस न फैले-rvpg मीडिया. लोगों से नशीली दवाओं का उपभोग करने की अपील करते हुए, डॉ. रमेश के. कौलगुड, संयुक्त निदेशक, राष्ट्रीय सदिश जनित रोग नियंत्रण कार्यक्रम (NVBCP), यह कहते हैं कि कलबुर्गी और बीड़ी जिलों में लसीका के लगभग 7,078 और 3424 मामले दर्ज किए गए हैं, जो लसीका के 405 और 346 मामलों में दर्ज किए गए हैं।:::जौंडिस और माध्य प्रदेश के कारण झाँसी में फाइलेरिया के मामले बढ़ रहे हैं: जहांसी में फाइलेरिया के मामले बढ़ रहे हैं, वर्तमान में, झाँसी में 94 फाइलेरिया के मरीज हैं।:::फाइलारियासिस का उन्मूलन: वाराणसी में रात का रक्त सर्वेक्षण अभियान 26 अगस्त से 8 ग्रामीण क्षेत्रों में और 24 शहरी क्षेत्रों में शुरू किया जाएगा।:::दवा फाइलेरियासिस का नाइट ब्लड सैंपल सर्वे पहले 500 सैंपल लिए गए थे, अब केवल 300 सैंपल लिए गए हैं।:::अधिकारियों के अनुसार, जिले में हाथियों के कुल 619 पुष्ट मामलों में से, जिनमें से अधिकांश-445 महिलाओं में पाए गए थे, पिछले दो वर्षों में कोई नया मामला सामने नहीं आया है, जिनमें से केवल 174 पुरुषों को ही यह बीमारी लगी थी।:::हालांकि, स्वास्थ्य विभाग के पास केवल 3005 लोगों को फाइलेरिया से संक्रमित होने का रिकॉर्ड है, हालांकि, एक वर्ष में एक बार, डीईसी एलबेंडजोल पिल फीडिंग पखवाड़े का संचालन किया जाता है, हालांकि, रोगियों की सटीक संख्या एक ही घर में बाईं ओर के पांच लोगों से संबंधित नहीं है, तीन लोग आसपास के क्षेत्रों में भी संक्रमित हैं।:::रात के रक्त प्लेटलेट संग्रह के बारे में लोगों में बहुत उत्साह था। पुरुषों के साथ<unk> साथ महिलाओं, बुजुर्गों और बच्चों ने भी फाइलेरिक स्क्रीनिंग में सक्रिय रूप से भाग लिया।:::जिले में फाइलेरिया रोगियों की संख्या दोगुनी से अधिक हो गई है. वर्ष 2018 में, जिले में 1,105 मरीजों की पहचान की गई, जिनमें से अब तक 1,105 मरीज ठीक हो चुके हैं।:::वेबसाइट पर मा सुब्रमणियन<unk> हिंडामिल कहा जाता है: तमिलनाडु में 8023 लोग चौथे चरण के अल्फांडाइज से प्रभावित होते हैं, वेबसाइट पर ma सुब्रमणियन कहते हैं: तमिलनाडु में 8,023 लोगों का इलाज चल रहा है।:::शहर के पॉश क्षेत्रों में फाइलेरिया के मरीज भी होते हैं। नागपुर खबरें-भारत का समय, नागपुर: जबकि फाइलेरिया या हाथी देश के अधिकांश भागों में स्थानिक हो रहे हैं, नागापुर जिले में छह तहसीलें और नागापुर में पांच क्षेत्र हैं।:::जिले में फाइलेरियासिस के 677 मरीज, एक बार फाइलेरिया बीमारी होने के बाद किट वितरण प्रारंभ हो गया, यह पूरी प्रकार से क्यूरेबल नहीं है"

# %%
dt = "जिले में फाइलेरिया के 6615 मरीजों को संचालन का लाभ मिला, जिले में फाइलेरिया के 6615 मरीज हैं।:::फिलारियासिस के बारे में बच्चों को जानकारी दी गईः भागलपुर, वरिष्ठ संवाददाता 23 बिहार बटालियन एनसीसी भागलपुर एनसीसी कैडेट्स ने शुक्रवार को फाइलेरिया के लिए सकारात्मक परीक्षण किया।:::फाइलारियासिस: कटनी और पन्ना में जाबपुर की चिंता को 27 से बढ़ाया जाएगा।:::राजकोट नगर निगम में 2007 के बाद हाथियों के 90 मामले दर्ज किए गए हैं, फिर भी 910 श्रमिकों के रक्त के नमूने लिए गए हैं-दिव्य भास्कार जो फाइलेरियासिस का एक भी मामला नहीं है, 2007 से राजकोट नगर निगम (आरएमसी) के स्वास्थ्य विभाग में रिपोर्ट की गई है, 2007 में, जब केवल 13 रोगियों को भर्ती किया गया था, तो राजकोट नगर निगम ने दावा किया कि बीमारी के पूर्ण उन्मूलन के बाद, शहर के विभिन्न भागों में निर्माण स्थलों पर काम करने वाले 910 श्रमिकों के रक्त के नमूने लिए गए थे।:::अहमदाबाद नगर निगम (एएमसी) स्वास्थ्य विभाग की टीम ने रैमोल, वात्वा, नोबलनगर, बापूनगर, इंद्रपुरी और अन्य स्थानों पर परीक्षण किए हैं।:::एमपी की कटनी में, 24 बच्चे बीमार हैं और 3 महत्वपूर्ण स्थिति में हैं. इसके कारण, सरकार बच्चों को फाइलेरिक दवा प्रदान करने के लिए एक अभियान चला रही है।:::फिलेरियासिस: एमडीए अभियान में कटनी मी में वितरित होने के बाद फाइलेरियासिस या भोजन विषाक्तता के कारण उल्टी होने की शिकायत करने वाले डॉक्टरों के 20 बच्चों को अस्पताल में भर्ती कराया गया है, सभी को अस्पताल में भर्ती कराया गया है।:::फिलारियासिस के 1100 मरीज अभी भी उत्तर प्रदेश के बांदा जिले में दुर्लभ फाइलरियासिस से पीड़ित सीएमओ 1100 स्वास्थ्य विभाग के अधिकारियों ने बताया कि फिलरियासिस उन्मूलन कार्यक्रम के तत्वावधान में आयोजित एक कार्यशाला में सीएमओ ने बताया कि जिले में फाइलरियासिस से पीड़ित 1100 मरीजों की पहचान उपचार के लिए की गई है।:::झारखंड के साहिबगंज में एक सरकारी स्कूल में फाइलेरियासिस दवा दिए जाने के बाद 40 बच्चे बीमार पड़ गए. जैसे ही बच्चों ने दवा ली, वैसे ही उन्हें उल्टी होने लगी. सभी को तुरंत अस्पताल में भर्ती कराया गया. इलाज के बाद उनकी स्थिति स्थिर बताई जाती है।:::फाइलेरियासिस दवा का उपयोग करने के बाद 25 बच्चे बिगड़ गए, सभी अस्पताल में भर्ती: सीएमओ 25 बच्चे फाइलेरीयल दवा के उपयोग के कारण बीमार हो गए, अस्पताल में भर्ती: सीएमओ:::फिलेरियासिस नयागढ़-ओरीसापोस्ट में टेन्टेकल फैलाता है। नयागढ़: लसिका नोड्स और लिम्फ वाहिनी को प्रभावित करने वाला एक परजीवी रोग, नयागढ़ जिले में अपने टेन्टेकल का प्रसार कर रहा है जो पहाड़ियों और वनों से घिरा हुआ है। जिले में टांगों में सूजन से पीड़ित 7,113 से अधिक मरीज और उनके स्क्रोम के घूर्णन से प्रभावित हैं।:::790 फाइलेरियासिस रोगियों में से, 75 का अभी तक उपचार नहीं किया गया है।:::पीलीभीत खबरें: जिले में 824 फाइलेरिया मामलों में 824 मामले दर्ज किए गए:::8 इकाइयों द्वारा पारित एंटिजन परीक्षण सर्वेक्षण 14: जहां एक प्रतिशत से कम फाइलेरिया मरीज पाए गए हैं-दैनिक भास्कर. तदनुसार, फाइलेरिया उन्मूलन कार्यक्रम के तहत एक ब्लॉक स्तर की इकाई बनाकर एक गहन सर्वेक्षण अभियान चलाया गया है।:::जिले में फाइलेरिया रोगियों की संख्या 1,532 है।"


print("\n".join(dt5.split(":::")),  file=open('filariasis_hindi1.txt', 'a'))

# %%
udhan_hindi = pd.read_csv('filariasis_hindi1.txt',sep=" ")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 udhan_hindi = pd.read_csv('filariasis_hindi1.txt',sep=" ")
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
lines = open("filariasis_hindi1.txt").read().splitlines()
#print(lines)

udaan_hindi = pd.DataFrame(lines,columns =['udaan_translated'])
udaan_hindi
# Out:
#                                      udaan_translated
# 0   जिले में फाइलेरिया के 6615 मरीजों को संचालन का...
# 1   फिलारियासिस के बारे में बच्चों को जानकारी दी ग...
# 2   फाइलारियासिस: कटनी और पन्ना में जाबपुर की चिंत...
# 3   राजकोट नगर निगम में 2007 के बाद हाथियों के 90 ...
# 4   अहमदाबाद नगर निगम (एएमसी) स्वास्थ्य विभाग की ट...
# 5   एमपी की कटनी में, 24 बच्चे बीमार हैं और 3 महत्...
# 6   फिलेरियासिस: एमडीए अभियान में कटनी मी में वितर...
# 7   फिलारियासिस के 1100 मरीज अभी भी उत्तर प्रदेश क...
# 8   झारखंड के साहिबगंज में एक सरकारी स्कूल में फाइ...
# 9   फाइलेरियासिस दवा का उपयोग करने के बाद 25 बच्चे...
# 10  फिलेरियासिस नयागढ़-ओरीसापोस्ट में टेन्टेकल फैल...
# 11  790 फाइलेरियासिस रोगियों में से, 75 का अभी तक ...
# 12  पीलीभीत खबरें: जिले में 824 फाइलेरिया मामलों म...
# 13  8 इकाइयों द्वारा पारित एंटिजन परीक्षण सर्वेक्ष...
# 14     जिले में फाइलेरिया रोगियों की संख्या 1,532 है।
# 15  300 से अधिक लोगों का परीक्षण किया गया, फाइलेरि...
# ...

# %%
df2 = pd.read_csv("filariasis_cleaned.csv")
result = pd.concat([df2,udaan_hindi])
result
# Out:
#           Disease Disease.keyword                ExtractedDate  \
# 0      Filariasis      Filariasis   Mar 5, 2023 @ 00:00:00.000
# 1      Filariasis      Filariasis  Feb 25, 2023 @ 00:00:00.000
# 2      Filariasis      Filariasis  Feb 23, 2023 @ 00:00:00.000
# 3   elephantiasis   elephantiasis  Feb 15, 2023 @ 00:00:00.000
# 4   elephantiasis   elephantiasis  Feb 14, 2023 @ 00:00:00.000
# ..            ...             ...                          ...
# 40            NaN             NaN                          NaN
# 41            NaN             NaN                          NaN
# 42            NaN             NaN                          NaN
# 43            NaN             NaN                          NaN
# 44            NaN             NaN                          NaN
#
#               ExtractedDateTime Incident Incident.keyword Incident_Type  \
# 0    Mar 5, 2023 @ 08:39:22.000     case             case         total
# ...

# %%
kala = pd.read_csv("kala.csv")
kala2 = kala["OriginalArticle"]
kala2.to_csv("kala_azar_hindi2.txt",index=False)

# %%
kala = pd.read_csv("filaria.csv")
kala2 = kala["OriginalArticle"]
kala2.to_csv("filariasis_hindi2.txt",index=False)

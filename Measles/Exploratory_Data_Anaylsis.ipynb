# %%
import numpy as np
import pandas as pd

# %%
df19=pd.read_excel("/content/drive/MyDrive/Seminar/2019_data.xlsx")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df20=pd.read_excel("/content/drive/MyDrive/Seminar/2020_data.xlsx")

# %%
df21=pd.read_excel("/content/drive/MyDrive/Seminar/2021_data.xlsx")

# %%
df22=pd.read_excel("/content/drive/MyDrive/Seminar/2022_data.xlsx")

# %%
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1638 entries, 0 to 1637
# Columns: 201 entries, Unit_Code to Reporting_District
# dtypes: datetime64[ns](29), float64(99), int64(1), object(72)
# memory usage: 2.5+ MB

# %%
df22['Age (years)'].value_counts()
# Out:
# 0.0     467
# 1.0     317
# 2.0     167
# 3.0     116
# 4.0     115
# 5.0      80
# 7.0      70
# 6.0      57
# 8.0      46
# 9.0      43
# 10.0     36
# 11.0     23
# 12.0     17
# 22.0      7
# 14.0      7
# 13.0      6
# 15.0      6
# 16.0      6
# 20.0      5
# 18.0      5
# 17.0      5
# 19.0      5
# 21.0      4
# 31.0      4
# 23.0      3
# 28.0      3
# 41.0      2
# 27.0      2
# 29.0      2
# 42.0      1
# 30.0      1
# 24.0      1
# 50.0      1
# 47.0      1
# 25.0      1
# 35.0      1
# 51.0      1
# 65.0      1
# 60.0      1
# 40.0      1
# 33.0      1
# Name: Age (years), dtype: int64

# %%
df22['Total Age= year.months'].min()
# Out:
# 0.0

# %%
df19['Total Age= year.months'].min()
# Out:
# 0.4166666667

# %%
df20['Total Age= year.months'].min()
# Out:
# 0.4166666667

# %%
df21['Total Age= year.months'].min()
# Out:
# 0.3333333333

# %% [markdown]
# Hidden cell in excel but we got max age =65 here since colab extracted info from hidden cells as well

# %%
df22[df22['Age (years)']==65]
# Out:
#       Unit_Code      CASE        Reporting District    Yr Case Number  \
# 304  MH_BMC_043  SPORADIC  GR. MUMBAI,(MAHARASHTRA)  22.0         071
#
#           EpidNumber If Case belongs to an outbreak Corresponding OB  \
# 304  MRINDMHBMC22071                            NaN              NaN
#
#      Corresponding Msl Date of notification  ... Newborn Status  \
# 304                NaN           2022-03-10  ...            NaN
#
#     Birth defect - Congenital heart defect Birth defect - Eye defect  \
# 304                                    0.0                       0.0
#
#     Birth defect - Hearing  defect Birth defect - Neurological deficit  \
# 304                            0.0                                 0.0
#
#     Birth defect - Endocrine deficit Birth defect - Other deficits    Class  \
# 304                              0.0                           0.0  Discard
#
#     Reporting_Block Reporting_District
# 304             NaN         GR. MUMBAI
#
# ...

# %%
df22['extracted_month'] = pd.DatetimeIndex(df22['Date of notification']).month

# %%
df22['extracted_month'].value_counts()
# Out:
# 11.0    822
# 12.0    194
# 10.0    129
# 9.0      97
# 7.0      86
# 8.0      83
# 3.0      48
# 6.0      47
# 5.0      45
# 2.0      32
# 4.0      32
# 1.0      21
# Name: extracted_month, dtype: int64

# %%
df22['Total Age= year.months'].round().value_counts()
# Out:
# 1.0     136
# 2.0      78
# 4.0      51
# 3.0      40
# 5.0      34
# 0.0      29
# 6.0      24
# 7.0      21
# 8.0      15
# 9.0      13
# 10.0     10
# 11.0      5
# 22.0      3
# 12.0      3
# 17.0      2
# 16.0      2
# 19.0      2
# 27.0      1
# 32.0      1
# 20.0      1
# 23.0      1
# 13.0      1
# 14.0      1
# 25.0      1
# Name: Total Age= year.months, dtype: int64

# %%
df22['Total Age= year.months'].max().round()
# Out:
# 32.0

# %%
df22['Total Age= year.months'].max().round()
# Out:
# 32.0

# %%
# for many dataset and  many columns
datasets = [df19,df20,df21,df22]
column_indexs = [-3]
# columns = ["Class"]  #by  columns name
# columns = dataset
for dataset in datasets:
  #columns = dataset.columns # for ALL Column
  for column_index in column_indexs:
    print(dataset[dataset.columns[column_index]].value_counts())
# Out:
# Measles Positive    37
# Name: Class, dtype: int64
# Measles Positive    30
# Name: Class, dtype: int64
# Measles Positive    10
# Name: Class, dtype: int64
# Series([], Name: Reporting_Block, dtype: int64)

# %% [markdown]
# # first 14 yellow colmns

# %%
df19['Reporting District'].value_counts()
# Out:
# GR. MUMBAI,( MAHARASHTRA )    37
# Name: Reporting District, dtype: int64

# %%
df19['Health Facility Type'].value_counts()
# Out:
# INF      17
# RU       14
# Other     6
# Name: Health Facility Type, dtype: int64

# %%
df19['Health Facility Category'].value_counts()
# Out:
# LP       22
# VHP       7
# Other     7
# HP        1
# Name: Health Facility Category, dtype: int64

# %%
df19['Health Facility Setup'].value_counts()
# Out:
# 2    21
# 1    15
# 8     1
# Name: Health Facility Setup, dtype: int64

# %%
df19['Sex'].value_counts()
# Out:
# M    22
# F    15
# Name: Sex, dtype: int64

# %%
df19['Religion'].value_counts()
# Out:
# H    25
# M    10
# O     2
# Name: Religion, dtype: int64

# %%
df19['District_Name'].value_counts()
# Out:
# GR. MUMBAI    31
# THANE          3
# PALGHAR        2
# SOLAPUR        1
# Name: District_Name, dtype: int64

# %%
df19['Migratory'].value_counts()
# Out:
# N    35
# Y     2
# Name: Migratory, dtype: int64

# %%
df19['Measles vaccine received'].value_counts()
# Out:
# Y    23
# N    13
# U     1
# Name: Measles vaccine received, dtype: int64

# %%
df19['MCV-1'].value_counts()
# Out:
# Y    23
# Name: MCV-1, dtype: int64

# %%
df19['MCV-1 Type'].value_counts()
# Out:
# M          17
# MMR         3
# MR          2
# Unknown     1
# Name: MCV-1 Type, dtype: int64

# %%
#pd.set_option('display.max_rows', None)
df19['Date of MCV-1 received'].value_counts()
# Out:
# 2017-04-25    1
# 2019-07-27    1
# 2019-08-08    1
# 2019-11-09    1
# 2019-04-09    1
# 2019-11-20    1
# 2018-01-19    1
# 2014-08-25    1
# 2013-10-05    1
# 2016-11-28    1
# 2018-06-05    1
# 2019-10-15    1
# 2014-12-01    1
# 2014-11-04    1
# 2016-06-28    1
# 2019-01-07    1
# 2018-07-21    1
# 2017-09-23    1
# 2019-09-21    1
# Name: Date of MCV-1 received, dtype: int64

# %%
df19['MCV-2'].value_counts()
# Out:
# Y    17
# Name: MCV-2, dtype: int64

# %%
df19['Date of MCV-2 received'].value_counts()
# Out:
# 2017-12-11    1
# 2019-02-04    1
# 2018-03-30    1
# 2019-06-18    1
# 2019-08-17    1
# 2017-01-31    1
# 2015-05-06    1
# 2015-08-14    1
# 2017-05-18    1
# 2014-05-20    1
# 2015-07-13    1
# 2019-07-13    1
# 2019-12-03    1
# Name: Date of MCV-2 received, dtype: int64

# %% [markdown]
# # Last 13 yellow Columns

# %%
df22['Class'].value_counts()
# Out:
# Discard                  691
# Lab Confirmed Measles    483
# Clinically Compatible    296
# Lab Confirmed Rubella     44
# Name: Class, dtype: int64

# %%
df22['If died, Date of death'].value_counts()
# Out:
# 2022-11-28    2
# 2022-11-13    2
# 2022-10-27    2
# 2022-07-30    1
# 2022-12-09    1
# 2022-12-12    1
# 2022-10-28    1
# 2022-11-19    1
# 2022-10-26    1
# 2022-11-09    1
# 2022-11-06    1
# 2022-12-13    1
# 2022-11-18    1
# Name: If died, Date of death, dtype: int64

# %%
df22['Clinician suspects  Rubella'].value_counts()
# Out:
# N    1590
# Y      43
# Name: Clinician suspects  Rubella, dtype: int64

# %%
df22['Clinician suspects Measles'].value_counts()
# Out:
# Y    1627
# N      11
# Name: Clinician suspects Measles, dtype: int64

# %%
df22['Joint Pain'].value_counts()
# Out:
# N    1613
# Y      21
# Name: Joint Pain, dtype: int64

# %%
df22['Enlarged lymph nodes'].value_counts()
# Out:
# N    1620
# Y      15
# Name: Enlarged lymph nodes, dtype: int64

# %%
df22['Conjuctivitis'].value_counts()
# Out:
# N    1309
# Y     327
# Name: Conjuctivitis, dtype: int64

# %%
df22['Coryza'].value_counts()
# Out:
# Y    903
# N    734
# Name: Coryza, dtype: int64

# %%
df22['Cough'].value_counts()
# Out:
# Y    977
# N    660
# Name: Cough, dtype: int64

# %%
df22['If campaign dose is missed, reason'].value_counts()
# Out:
# Campaign not held    752
# Refusal               37
# Awareness gap         29
# Others                18
# Operational gap       14
# Child travelling       5
# AEFI apprehension      4
# Name: If campaign dose is missed, reason, dtype: int64

# %%
df22['Total MCV Doses'].value_counts()
# Out:
# 0.0    710
# 2.0    429
# 1.0    256
# 3.0    149
# Name: Total MCV Doses, dtype: int64

# %%
df22['No. of Measles doses received through campaign (SIA)'].value_counts()
# Out:
# 0.0     567
# 99.0    357
# 1.0     158
# 2.0       3
# Name: No. of Measles doses received through campaign (SIA), dtype: int64
